# %%
from pathlib import Path
from src.llm import get_quiz
from src.render import render_quiz_to_html

IN_PATH  = Path("data/transcripts/example.txt")
OUT_PATH = Path("data/examples/quiz_output.html")

text = IN_PATH.read_text(encoding="utf-8")
quiz = get_quiz(text)                # one call, no retries
html = render_quiz_to_html(quiz)
OUT_PATH.write_text(html, encoding="utf-8")
print(f"Wrote {OUT_PATH}")
# Out:
# Wrote data/examples/quiz_output.html
